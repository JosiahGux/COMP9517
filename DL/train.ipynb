# %%
#裁切照片
from DL.generate_detector_crops import generate_detector_crops

DET_WEIGHTS = "detector/runs/detect/weights/best.pt"
DATA_ROOT   = "archive"          # 里面有 train/valid/test/images
OUT_ROOT    = "det_crops"        # 新的分类数据集根目录
CLASS_NAMES = ["Ants","Bees","Beetles","Caterpillars",
               "Earthworms","Earwigs","Grasshoppers","Moths",
               "Slugs","Snails","Wasps","Weevils"]

generate_detector_crops(
    det_weights=DET_WEIGHTS,
    data_root=DATA_ROOT,
    out_root=OUT_ROOT,
    splits=("train","valid","test"),
    img_subdir="images",
    conf=0.25,
    iou=0.45,
    img_size=640,
    class_names=CLASS_NAMES,
)
# Out:
# [INFO] 处理 train 集: 11502 张图片
# 100%|██████████| 11502/11502 [1:11:46<00:00,  2.67it/s]
# [INFO] 处理 valid 集: 1095 张图片
# 100%|██████████| 1095/1095 [08:06<00:00,  2.25it/s]
# [INFO] 处理 test 集: 546 张图片
# 100%|██████████| 546/546 [04:03<00:00,  2.25it/s]
# [DONE] 所有裁剪图片已保存到: det_crops
