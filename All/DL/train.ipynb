# %%
#裁切照片
from All.DL.generate_detector_crops import generate_detector_crops

DET_WEIGHTS = "detector/runs/detect/weights/best.pt"
DATA_ROOT   = "archive"          # 里面有 train/valid/test/images
OUT_ROOT    = "det_crops"        # 新的分类数据集根目录
CLASS_NAMES = ["Ants","Bees","Beetles","Caterpillars",
               "Earthworms","Earwigs","Grasshoppers","Moths",
               "Slugs","Snails","Wasps","Weevils"]

generate_detector_crops(
    det_weights=DET_WEIGHTS,
    data_root=DATA_ROOT,
    out_root=OUT_ROOT,
    splits=("train","valid","test"),
    img_subdir="images",
    conf=0.25,
    iou=0.45,
    img_size=640,
    class_names=CLASS_NAMES,
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/Users/gzx/Library/Application Support/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# [INFO] 处理 train 集: 11502 张图片
#   6%|▌         | 700/11502 [06:30<1:40:22,  1.79it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 11
#       6 OUT_ROOT    = "det_crops"        # 新的分类数据集根目录
#       7 CLASS_NAMES = ["Ants","Bees","Beetles","Caterpillars",
#       8                "Earthworms","Earwigs","Grasshoppers","Moths",
#       9                "Slugs","Snails","Wasps","Weevils"]
# ---> 11 generate_detector_crops(
#      12     det_weights=DET_WEIGHTS,
#      13     data_root=DATA_ROOT,
# ...
